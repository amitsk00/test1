# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("./cars.csv")
df
# Out:
#     YEAR        Make                            Model                   Size  \
# 0   2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 1   2012      NISSAN                             LEAF               MID-SIZE
# 2   2013        FORD                   FOCUS ELECTRIC                COMPACT
# 3   2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 4   2013      NISSAN                             LEAF               MID-SIZE
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 7   2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 8   2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# ...

# %%
#df.pivot(index="Make" , columns="Size", values="(km)")

df.columns
# Out:
# Index(['YEAR', 'Make', 'Model', 'Size', '(kW)', 'Unnamed: 5', 'TYPE',
#        'CITY (kWh/100 km)', 'HWY (kWh/100 km)', 'COMB (kWh/100 km)',
#        'CITY (Le/100 km)', 'HWY (Le/100 km)', 'COMB (Le/100 km)', '(g/km)',
#        'RATING', '(km)', 'TIME (h)'],
#       dtype='object')

# %%
df.groupby(by=["Type"]).max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-42ae6249cf85> in <module>()
# ----> 1 df.groupby(by=["Type"]).max()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6657         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6658                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6659                        observed=observed, **kwargs)
#    6660
#    6661     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ...

# %% [markdown]
# df

# %%
df_top = df.sort_values(by="(km)", ascending=False)
df_top
# Out:
#     YEAR        Make                            Model                   Size  \
# 48  2016       TESLA            MODEL S 90D (Refresh)              FULL-SIZE
# 32  2015       TESLA                  MODEL S 85D/90D              FULL-SIZE
# 50  2016       TESLA           MODEL S P90D (Refresh)              FULL-SIZE
# 47  2016       TESLA                  MODEL S 85D/90D              FULL-SIZE
# 19  2014       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# 18  2014       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# 45  2016       TESLA      MODEL S (85/90 kWh battery)              FULL-SIZE
# 30  2015       TESLA      MODEL S (85/90 kWh battery)              FULL-SIZE
# 51  2016       TESLA                      MODEL X 90D         SUV - STANDARD
# ...

# %%
df.Size
# Out:
# 0                SUBCOMPACT
# 1                  MID-SIZE
# 2                   COMPACT
# 3                SUBCOMPACT
# 4                  MID-SIZE
# 5                TWO-SEATER
# 6                TWO-SEATER
# 7                 FULL-SIZE
# 8                 FULL-SIZE
# 9                 FULL-SIZE
# 10                FULL-SIZE
# 11               SUBCOMPACT
# 12                  COMPACT
# 13               SUBCOMPACT
# 14                 MID-SIZE
# 15               TWO-SEATER
# 16               TWO-SEATER
# 17                FULL-SIZE
# 18                FULL-SIZE
# 19                FULL-SIZE
# 20               SUBCOMPACT
# 21               SUBCOMPACT
# 22                  COMPACT
# 23    STATION WAGON - SMALL
# 24               SUBCOMPACT
# 25                 MID-SIZE
# 26               TWO-SEATER
# 27               TWO-SEATER
# 28                FULL-SIZE
# 29                FULL-SIZE
# 30                FULL-SIZE
# 31                FULL-SIZE
# 32                FULL-SIZE
# ...

# %%
df_suv = df[df.Size == "FULL-SIZE"]
df_suv
# Out:
#     YEAR   Make                        Model       Size  (kW) Unnamed: 5 TYPE  \
# 7   2013  TESLA     MODEL S (40 kWh battery)  FULL-SIZE   270         A1    B
# 8   2013  TESLA     MODEL S (60 kWh battery)  FULL-SIZE   270         A1    B
# 9   2013  TESLA     MODEL S (85 kWh battery)  FULL-SIZE   270         A1    B
# 10  2013  TESLA          MODEL S PERFORMANCE  FULL-SIZE   310         A1    B
# 17  2014  TESLA     MODEL S (60 kWh battery)  FULL-SIZE   225         A1    B
# 18  2014  TESLA     MODEL S (85 kWh battery)  FULL-SIZE   270         A1    B
# 19  2014  TESLA          MODEL S PERFORMANCE  FULL-SIZE   310         A1    B
# 28  2015  TESLA     MODEL S (60 kWh battery)  FULL-SIZE   283         A1    B
# 29  2015  TESLA     MODEL S (70 kWh battery)  FULL-SIZE   283         A1    B
# 30  2015  TESLA  MODEL S (85/90 kWh battery)  FULL-SIZE   283         A1    B
# 31  2015  TESLA                  MODEL S 70D  FULL-SIZE   280         A1    B
# ...

# %%
df.nlargest(5,"(km)")
# Out:
#     YEAR   Make                     Model       Size  (kW) Unnamed: 5 TYPE  \
# 48  2016  TESLA     MODEL S 90D (Refresh)  FULL-SIZE   386         A1    B
# 32  2015  TESLA           MODEL S 85D/90D  FULL-SIZE   280         A1    B
# 47  2016  TESLA           MODEL S 85D/90D  FULL-SIZE   386         A1    B
# 50  2016  TESLA    MODEL S P90D (Refresh)  FULL-SIZE   568         A1    B
# 9   2013  TESLA  MODEL S (85 kWh battery)  FULL-SIZE   270         A1    B
#
#     CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 48               20.8              19.7               20.3               2.3
# 32               22.0              19.8               21.0               2.5
# 47               22.0              19.8               21.0               2.5
# 50               22.9              21.0               22.1               2.6
# 9                23.8              23.2               23.6               2.7
#
# ...

# %%
df.Size.unique()
df.index
# Out:
# RangeIndex(start=0, stop=53, step=1)

# %%
i = 0
df_final = df[df.Size == 'X'][["Make","Model","(km)","TIME (h)"]]
df_final.columns
print("----")

#df_temp = df[df.Size == "FULL-SIZE"].nlargest(2,"(km)")
#df_temp[['Make','Model','(km)','TIME (h)']]
#print(df_temp[['Year','Make','Model','(km)','TIME (h)']])

for zz in df.Size.unique():
    df_temp = df[df.Size == zz].nlargest(2,"(km)")
    #print(df_temp[['Make','Model','(km)','TIME (h)']])
    df_final.append(df_temp[["Make","Model","(km)","TIME (h)"]], ignore_index=True, sort=False)

df_final
# Out:
# ----
# Empty DataFrame
# Columns: [Make, Model, (km), TIME (h)]
# Index: []
